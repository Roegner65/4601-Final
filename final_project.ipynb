# %% [markdown]
# # The Genetic Algorithm
# ### CSC4601 121 | Final Project | Evan Roegner, Louis Link
# ---

# %%
import numpy as np
from random import randint

from neural_network import NeuralNetwork
from genetic_algorithm import Generation, Agent

# %%
template = NeuralNetwork(2)
template.add_layer(3)
template.add_layer(2)

# %%
def sign(n):
    return -1 if n < 0 else 1

# %%
class Tester:
    def __init__(self, x:float, y:float, brain:Agent):
        self.brain = brain
        self.x = x
        self.y = y
    
    def move(self, max_x, max_y):
        output = self.brain.predict(np.array([self.x, self.y]))
        # x_move = output[0] / abs(output[0]+ 0.00000000001)
        # y_move = output[1] / abs(output[1] + 0.00000000001)
        if abs(output[0]) > 0.5:
            self.x += sign(output[0])
        if abs(output[1]) > 0.5:
            self.y += sign(output[1])
        # print(output[1], output[1] / abs(output[1]+ 0.00000000001))
        # print(output)

        self.x = min(max(self.x, 0), max_x - 1)
        self.y = min(max(self.y, 0), max_y - 1)

# %%
def populate_testers(generation:Generation, field_size):
    return [Tester(randint(0, field_size[0]), randint(0, field_size[1]), agent) for agent in generation.agents]

# %%
from IPython.display import clear_output
import time

def display_testers(testers, field_size):
    output = ''
    for x in range(field_size[0]):
        for y in range(field_size[1]):
            occupied = False
            for tester in testers:
                if int(tester.x) == x and int(tester.y) == y:
                    occupied = True
            
            if occupied:
                output += ' # '
            elif x == field_size[0] / 2 and y == field_size[1] / 2:
                output += ' G '
            else:
                output += '   '

        output += '\n'
    clear_output(wait=True)
    print(output)
    time.sleep(0.05)

# %%
def run_generation(testers, field_size, num_time_steps=10):
    for t in range(num_time_steps):
        for tester in testers:
            tester.move(field_size[0], field_size[1])
        display_testers(testers, field_size)  
    for tester in testers:
        tester.brain.score -= (tester.x - field_size[0]/2)**2 + (tester.y - field_size[1]/2)**2
        # Score is lower further from the center of the field, reaching 0 in corners.
    # time.sleep(10)

# %%
def randomize_testers(testers, field_size):
    for tester in testers:
        tester.x = randint(0, field_size[0])
        tester.y = randint(0, field_size[1])

# %%
gen = Generation(template=template)

field_size = (16, 16)
testers = populate_testers(gen, field_size)
display_testers(testers, field_size)
# print(testers[0].brain.network)
# print(testers[1].brain.network)
num_gens = 1000

for gen_num in range(num_gens):
    for _ in range(5):
        run_generation(testers, field_size)
        randomize_testers(testers, field_size)
    gen = gen.next_generation()
    testers = populate_testers(gen, field_size)
    print(f'NEW GEN! gen {gen_num}/{num_gens}')
    time.sleep(0.8)
# Out:
#                                #           #
#                    #                    #
#  #  #        #     #                 #     #  #
#  #     #           #  #     #
#              #              #  #
#           #           #     #        #        #
#     #     #                 #     #        #  #
#                    #                 #  #
#           #              G     #     #  #
#                                   #
#        #  #  #  #           #  #
#  #           #                       #  #
#  #  #                 #     #  #     #     #  #
#  #  #  #        #                 #
#  #                                #  #  #
#     #  #        #  #  #           #        #  #
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 12
#      10 for gen_num in range(num_gens):
#      11     for _ in range(5):
# ---> 12         run_generation(testers, field_size)
#      13         randomize_testers(testers, field_size)
#      14     gen = gen.next_generation()
#
# Cell In[17], line 5, in run_generation(testers, field_size, num_time_steps)
#       3     for tester in testers:
#       4         tester.move(field_size[0], field_size[1])
# ----> 5     display_testers(testers, field_size)
#       6 for tester in testers:
#       7     tester.brain.score -= (tester.x - field_size[0]/2)**2 + (tester.y - field_size[1]/2)**2
#
# Cell In[16], line 21, in display_testers(testers, field_size)
#      18             output += '   '
#      20     output += '\n'
# ---> 21 clear_output(wait=True)
#      22 print(output)
#      23 time.sleep(0.05)
#
# File c:\Users\linkl\OneDrive - Milwaukee School of Engineering\Desktop\Semester 1\Theory of ML\Final Project\4601-Final\.venv\Lib\site-packages\IPython\core\display_functions.py:366, in clear_output(wait)
#     364 from IPython.core.interactiveshell import InteractiveShell
#     365 if InteractiveShell.initialized():
# --> 366     InteractiveShell.instance().display_pub.clear_output(wait)
#     367 else:
#     368     print('\033[2K\r', end='')
#
# File c:\Users\linkl\OneDrive - Milwaukee School of Engineering\Desktop\Semester 1\Theory of ML\Final Project\4601-Final\.venv\Lib\site-packages\ipykernel\zmqshell.py:194, in ZMQDisplayPublisher.clear_output(self, wait)
#     183 """Clear output associated with the current execution (cell).
#     184
#     185 Parameters
#    (...)    191
#     192 """
#     193 content = dict(wait=wait)
# --> 194 self._flush_streams()
#     195 assert self.session is not None
#     196 msg = self.session.msg("clear_output", json_clean(content), parent=self.parent_header)
#
# File c:\Users\linkl\OneDrive - Milwaukee School of Engineering\Desktop\Semester 1\Theory of ML\Final Project\4601-Final\.venv\Lib\site-packages\ipykernel\zmqshell.py:93, in ZMQDisplayPublisher._flush_streams(self)
#      91 def _flush_streams(self):
#      92     """flush IO Streams prior to display"""
# ---> 93     sys.stdout.flush()
#      94     sys.stderr.flush()
#
# File c:\Users\linkl\OneDrive - Milwaukee School of Engineering\Desktop\Semester 1\Theory of ML\Final Project\4601-Final\.venv\Lib\site-packages\ipykernel\iostream.py:599, in OutStream.flush(self)
#     588 """trigger actual zmq send
#     589
#     590 send will happen in the background thread
#     591 """
#     592 if (
#     593     self.pub_thread
#     594     and self.pub_thread.thread is not None
#    (...)    597 ):
#     598     # request flush on the background thread
# --> 599     self.pub_thread.schedule(self._flush)
#     600     # wait for flush to actually get through, if we can.
#     601     evt = threading.Event()
#
# File c:\Users\linkl\OneDrive - Milwaukee School of Engineering\Desktop\Semester 1\Theory of ML\Final Project\4601-Final\.venv\Lib\site-packages\ipykernel\iostream.py:268, in IOPubThread.schedule(self, f)
#     266     self._events.append(f)
#     267     # wake event thread (message content is ignored)
# --> 268     self._event_pipe.send(b"")
#     269 else:
#     270     f()
#
# File c:\Users\linkl\OneDrive - Milwaukee School of Engineering\Desktop\Semester 1\Theory of ML\Final Project\4601-Final\.venv\Lib\site-packages\zmq\sugar\socket.py:698, in Socket.send(self, data, flags, copy, track, routing_id, group)
#     691         data = zmq.Frame(
#     692             data,
#     693             track=track,
#     694             copy=copy or None,
#     695             copy_threshold=self.copy_threshold,
#     696         )
#     697     data.group = group
# --> 698 return super().send(data, flags=flags, copy=copy, track=track)
#
# File c:\Users\linkl\OneDrive - Milwaukee School of Engineering\Desktop\Semester 1\Theory of ML\Final Project\4601-Final\.venv\Lib\site-packages\zmq\backend\cython\_zmq.py:1152, in zmq.backend.cython._zmq.Socket.send()
#    1149     rc: C.int = zmq_leave(self.handle, group)
#    1150     _check_rc(rc)
# -> 1152 def send(self, data, flags=0, copy: bint = True, track: bint = False):
#    1153     """
#    1154     Send a single zmq message frame on this socket.
#    1155
#    (...)   1192
#    1193     """
#    1194     _check_closed(self)
#
# File c:\Users\linkl\OneDrive - Milwaukee School of Engineering\Desktop\Semester 1\Theory of ML\Final Project\4601-Final\.venv\Lib\site-packages\zmq\backend\cython\_zmq.py:1200, in zmq.backend.cython._zmq.Socket.send()
#    1197     raise TypeError("unicode not allowed, use send_string")
#    1199 if copy and not isinstance(data, Frame):
# -> 1200     return _send_copy(self.handle, data, flags)
#    1201 else:
#    1202     if isinstance(data, Frame):
#
# File c:\Users\linkl\OneDrive - Milwaukee School of Engineering\Desktop\Semester 1\Theory of ML\Final Project\4601-Final\.venv\Lib\site-packages\zmq\backend\cython\_zmq.py:1468, in zmq.backend.cython._zmq._send_copy()
#    1466     rc = zmq_msg_send(address(msg), handle, flags)
#    1467 try:
# -> 1468     _check_rc(rc)
#    1469 except InterruptedSystemCall:
#    1470     continue
#
# File c:\Users\linkl\OneDrive - Milwaukee School of Engineering\Desktop\Semester 1\Theory of ML\Final Project\4601-Final\.venv\Lib\site-packages\zmq\backend\cython\_zmq.py:179, in zmq.backend.cython._zmq._check_rc()
#     174 """internal utility for checking zmq return condition
#     175
#     176 and raising the appropriate Exception class
#     177 """
#     178 errno: C.int = _zmq_errno()
# --> 179 PyErr_CheckSignals()
#     180 if errno == 0 and not error_without_errno:
#     181     return 0
#
# KeyboardInterrupt:

# %%
import pygame

pygame.init()

def display_testers(testers):
    screen.fill((0, 0, 0))
    for tester in testers:
        pygame.draw.circle(screen, (255, 255, 255), (tester.x * scale, tester.y * scale), 3 * scale)
    pygame.display.update()
    time.sleep(0.05)

gen = Generation(template=template)

field_size = (16, 16)
scale = 10
screen = pygame.display.set_mode((field_size[0] * scale, field_size[1] * scale))

testers = populate_testers(gen, field_size)
display_testers(testers)
num_gens = 1000

running = True
for gen_num in range(num_gens):
    for _ in range(5):
        run_generation(testers, field_size)
        randomize_testers(testers, field_size)
    gen = gen.next_generation()
    testers = populate_testers(gen, field_size)
    print(f'NEW GEN! gen {gen_num}/{num_gens}')
    time.sleep(0.8)
    for event in pygame.event.get():  
        if event.type == pygame.QUIT:  
           running = False
    if not running:
        break
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 25
#      23 for gen_num in range(num_gens):
#      24     for _ in range(5):
# ---> 25         run_generation(testers, field_size)
#      26         randomize_testers(testers, field_size)
#      27     gen = gen.next_generation()
#
# Cell In[17], line 5, in run_generation(testers, field_size, num_time_steps)
#       3     for tester in testers:
#       4         tester.move(field_size[0], field_size[1])
# ----> 5     display_testers(testers, field_size)
#       6 for tester in testers:
#       7     tester.brain.score -= (tester.x - field_size[0]/2)**2 + (tester.y - field_size[1]/2)**2
#
# TypeError: display_testers() takes 1 positional argument but 2 were given
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
